# %% [markdown]
# # 1. 네이버 뉴스 Crawling with Naver Open API

# %%
# 네이버 검색 API 예제 -  블로그 검색 예제를 뉴스 검색 예제로 수정하여 실행
import os
import sys
import urllib.request
client_id = "fectRRiU4hHDSgWp0PYL"
client_secret = "CRcxk6VH6p"

encText = urllib.parse.quote("인공지능")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %%
# 네이버 검색 API 예제 기반으로 네이버 검색 API 동작 방식 확인 (검색 결과 모두 받기)
# rescode가 200인 동안 start를 증가시켜서 계속 검색 (테스트를 위해 start는 25이하로 제한)
import os
import sys
import urllib.request
client_id = "fectRRiU4hHDSgWp0PYL"
client_secret = "CRcxk6VH6p"
encText = urllib.parse.quote("인공지능")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과

start = 1
display = 20
rescode = 200
while rescode == 200 and start < 100:
    new_url = url + f'&start={start}&display={display}'
    request = urllib.request.Request(new_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)

    start += display

# %% [markdown]
# # 2. NaverNewsCrawler 개발
# 1. 네이버 뉴스 API로 Crawling : **crawlNaverNews(keyword)** -> 파이썬 json 데이터
# 1. 응답데이터를 리스트에 저장 : **mergeResultToList(result_list, merged_list)** -> List
# 1. 응답데이터가 없을 때까지 반복
# 1. 리스트를 CSV 파일로 저장 : **saveJSONListToCSV(merged_list, csv_filename)**

# %%
# 검색 API 호출, 응답을 JSON 데이터로 return하는 함수 작성
# API 호출 결과에 문제가 있을 경우 exception으로 처리
# exception 발생 시 exception과 호출 url 확인 (try : ... except Exception as e: ... )

import os
import sys
import urllib.request
import json
import time


def crawlNaverNews(keyword, start, display=10):

    client_id = "fectRRiU4hHDSgWp0PYL"
    client_secret = "CRcxk6VH6p"
    encText = urllib.parse.quote("인공지능")
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과


    new_url = url + f'&start={start}&display={display}'
    request = urllib.request.Request(new_url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if rescode==200:
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        # json 문자열을 파이썬 객체로 변환
        py_data = json.loads(json_data)
        time.sleep(1)
        return py_data
    else:
        print("Error Code:" + rescode)
        return None

# %%
# 응답데이터를 리스트에 통합

def mergeResultToList(result_list, merged_list):
    
    for result in result_list:
        merged_list.append(result)

# %%
# JSON의 list를 dataframe으로 변환하여 csv 파일로 저장

# %%
keyword = '인공지능'

# API 호출 결과 전송된 JSON이 없거나, 전송된 JSON에 검색 결과가 없을 때까지
# 검색 결과를 JSON의 list로 저장 후 검색 API 추가 호출

# 검색 결과를 저장할 list 초기화
resultAll = []

start = 1

while start < 20:

    crawled_data = crawlNaverNews(keyword, start)

    if crawled_data:

        #print(crawled_data)
        print('crwaling 성공 :', start)
        resultAll += crawled_data['items']
        start += 10
    else:

        print('crawling 실패 :', start)
        break
# Out:
# crwaling 성공 : 1
# crwaling 성공 : 11

# %%
resultAll[:2]
# Out:
# [{'title': '컴퓨터학원 실용적인 <b>인공지능</b> 수업과정',
#   'link': 'https://blog.naver.com/foryou1035/224160610941',
#   'description': '요즘 <b>인공지능</b>이 화두인데요. 처음에는 똑똑한 기능에 신기함이 컸지만, 시간이 갈수록 미묘한 감정이... 현재는 직장에서 <b>인공지능</b> 교육을 담당하게 되었고, 퇴근 후에는 취미로 웹사이트를 만들고 있어요.... ',
#   'bloggername': 'Ssong Story ♡',
#   'bloggerlink': 'blog.naver.com/foryou1035',
#   'postdate': '20260126'},
#  {'title': '<b>인공지능</b> 자격증 취득과정 및 취업 정보 정리',
#   'link': 'https://blog.naver.com/gustlr00/224087574160',
#   'description': '<b>인공지능</b> 자격증 취득과정 및 취업 정보 정리 “AI를 이해하는 사람과 그렇지 못한 사람의 차이가 점점 더 커지고 있다&quot;라는 말을 실감하게 되는 요즘, 직장 내에서도, 취업 시장에서도 <b>인공지능</b> 기술을 다룰... ',
#   'bloggername': '〃다시 만나는 그날 까지 〃',
#   'bloggerlink': 'blog.naver.com/gustlr00',
#   'postdate': '20251125'}]

# %%
import pandas as pd
data_df = pd.DataFrame(resultAll)
result_filename = f'./data/{keyword}_naver_news.csv'
data_df.to_csv(result_filename)

# %%
# 검색어 입력
keyword = '인공지능'



# 검색 결과를 저장할 list 초기화
resultAll = []

# 첫 검색 API 호출 데이터 초기화
start = 1
display = 10
while True:
    crawled_data = crawlNaverNews(keyword, start)
    # API 호출 성공 여부 출력
    if crawled_data:
        print(f'{keyword} [{start}] : 검색 성공')
    else:
        print(f'{keyword} [{start}] : 검색 실패')
        break
    
    # crawling된 데이터가 없으면 중지

    # 응답데이터 정리하여 리스트로 통합
    mergeResultToList(crawled_data, merged_list) 
    # 다음 검색 API 호출을 위한 파라미터 조정
    start += display


# 리스트를 csv 파일로 저장

# %%
# 저장한 파일을 dataframe으로 loading 해보기
loaded_data_df = pd.read_csv(result_filename, index_col=0)
loaded_data_df
# Out:
#                                                 title  \
# 0                         컴퓨터학원 실용적인 <b>인공지능</b> 수업과정
# 1                     <b>인공지능</b> 자격증 취득과정 및 취업 정보 정리
# 2                          <b>인공지능</b>전문가 자격증 취득과정 정리
# 3               학점은행제 <b>인공지능</b> 학위로 AI회사에 이직 성공했어요.
# 4                숙명여대 편입, <b>인공지능</b>공학부 합격까지 인서울 도전기
# 5         엘지 LG 통돌이 세탁기 추천 용량 17kg <b>인공지능</b> T17WX3
# 6                <b>인공지능</b> 교육 AI교육 키트 언플러그드 코딩 주미AI
# 7          [연수기록] <b>인공지능</b> 맞춤형 교수학습 플랫폼(AIEP) 전달연수
# 8                            <b>인공지능</b> 자격증 취득방법 총정리
# 9              <b>인공지능</b>(AI) 시대, 앞으로 일자리는 어떻게 변할까요?
# 10              경기 용인 냉동 창고 시설 <b>인공지능</b> CCTV 설치 후기
# 11            생성형 <b>인공지능</b> 뜻, 챗지피티·제미나이·클라우드 모델 비교
# 12               AI학원, <b>인공지능</b> 전문가로 성장하는 가장 빠른 방법
# 13                        <b>인공지능</b>전문가 자격증 취득방법 총정리
# 14              학점은행제 <b>인공지능</b>, 학위 따고 재취업 성공(비전공자)
# 15                  직장인 Ai 활용 능력 기르는 <b>인공지능</b> 학사학위
# 16         몰트북 충격 읽어보니 AI 시대 얼마나 바뀔까 <b>인공지능</b> 책 추천
# 17                   학점은행제 <b>인공지능</b> 온라인으로 학위 취득했어요
# 18              최소한의 수학』 <b>인공지능</b>을 이해하는 가장 현실적인 방법
# 19  NVIDIA GTC 2026에서 본 <b>인공지능</b> 반도체의 미래! GPU, ...
#
#                                                 link  \
# 0     https://blog.naver.com/foryou1035/224160610941
# 1       https://blog.naver.com/gustlr00/224087574160
# 2    https://blog.naver.com/anycall2502/224076021636
# 3     https://blog.naver.com/seo8810603/224226152116
# 4       https://blog.naver.com/spoly001/224114522439
# 5        https://blog.naver.com/reser45/224246855986
# 6      https://blog.naver.com/alley1980/224229641240
# 7      https://blog.naver.com/dndus3356/224196778376
# 8   https://blog.naver.com/wwevoszmffjq/224063279444
# 9     https://blog.naver.com/molab_suda/224242653040
# 10      https://blog.naver.com/xavisnet/224220577252
# 11  https://blog.naver.com/teamlinchpin/224177479277
# 12   https://blog.naver.com/himediacokr/224231103099
# 13      https://blog.naver.com/gustlr00/224076037551
# 14        https://blog.naver.com/jje423/224228420448
# 15    https://blog.naver.com/seo8810603/224224382865
# 16     https://blog.naver.com/limhyunae/224248225786
# 17      https://blog.naver.com/reebbang/224181846192
# 18       https://blog.naver.com/sandhya/224206770826
# 19  https://blog.naver.com/nststory2014/224251065664
#
#                                           description  \
# 0   요즘 <b>인공지능</b>이 화두인데요. 처음에는 똑똑한 기능에 신기함이 컸지만, ...
# 1   <b>인공지능</b> 자격증 취득과정 및 취업 정보 정리 “AI를 이해하는 사람과 ...
# 2   <b>인공지능</b>전문가 자격증 취득과정 정리 최근 <b>인공지능</b> 기술이 ...
# 3   저는 학점은행제 <b>인공지능</b> 학위로 이직까지 성공하게 된 30대 박ㅇ우입니...
# 4   최근 IT와 AI 분야의 인재 양성에 주력하며 <b>인공지능</b>공학부를 신설해 ...
# 5   기술의 발전은 여기서 그치지 않고 <b>인공지능</b> AI과 결합되었습니다. LG...
# 6   <b>인공지능</b> 교육 AI교육 키트 언플러그드 코딩 주미AI 어느덧 따스한 바...
# 7   <b>인공지능</b> 맞춤형 교수학습 플랫폼(AIEP) 전남 - 아이모두 학교 담당...
# 8   <b>인공지능</b> 자격증 취득방법 총정리 그래픽 디자인을 전공하고 5년 동안 근...
# 9   - ｢APEC 미래 일자리 포럼: <b>인공지능</b>(AI)와 인구구조 변화｣ 개...
# 10  경기 용인 냉동 창고 시설 <b>인공지능</b> CCTV 설치 후기 안녕하세요, 자...
# 11  생성형 <b>인공지능</b> 뜻, 챗지피티·제미나이·클라우드 모델 비교 요즘 뉴스,...
# 12  최근 AI 대전환이라 느껴질 만큼 우리 주변의 모든 산업이 <b>인공지능</b>을 ...
# 13  <b>인공지능</b>전문가 자격증 취득방법 총정리 요즘 AI 관련 뉴스가 하루가 다...
# 14  학점은행제 <b>인공지능</b>, 학위 따고 재취업 성공(비전공자) 안녕하세요! 4...
# 15  과정으로 <b>인공지능</b> 공학으로 4년제 학사학위를 취득했어요. 온라인으로 학...
# 16  몰트북 충격 읽어보니 AI 시대 얼마나 바뀔까 <b>인공지능</b> 책 추천 요즘 ...
# 17  저는 비전공자로 직장 생활을 하다가 미래를 위해 학점은행제 <b>인공지능</b> 전...
# 18  AI가 쉬워지는 최소한의 수학 이동준2026지상의책(갈매나무) 사람들은 <b>인공지...
# 19  <b>인공지능</b> 기술은 단순한 알고리즘 경쟁을 넘어, 실제 구현과 운영을 포함...
#
#                            bloggername                  bloggerlink  postdate
# 0                        Ssong Story ♡    blog.naver.com/foryou1035  20260126
# 1                      〃다시 만나는 그날 까지 〃      blog.naver.com/gustlr00  20251125
# 2                        더불어 사는 세상 이도형   blog.naver.com/anycall2502  20251114
# 3   Seo's reptile and Water life story    blog.naver.com/seo8810603  20260323
# 4                  TV조선캠퍼스평생교육원 공식 블로그      blog.naver.com/spoly001  20251218
# 5                                 무스미엘       blog.naver.com/reser45  20260409
# 6                          고고씨네 소소한 일상     blog.naver.com/alley1980  20260325
# 7                          우연샘의 꿈꾸는 교실     blog.naver.com/dndus3356  20260226
# 8                             왜 안 가인요?  blog.naver.com/wwevoszmffjq  20251103
# 9                         고용노동부 공식 블로그    blog.naver.com/molab_suda  20260406
# 10                            XAVISnet      blog.naver.com/xavisnet  20260318
# 11                       온라인마케팅, 린치핀기획  blog.naver.com/teamlinchpin  20260209
# 12                    하이미디어 아카데미 공식블로그   blog.naver.com/himediacokr  20260327
# 13                     〃다시 만나는 그날 까지 〃      blog.naver.com/gustlr00  20251114
# 14                        욕심많은 별들맘 이야기        blog.naver.com/jje423  20260325
# 15  Seo's reptile and Water life story    blog.naver.com/seo8810603  20260321
# 16                          달달한 그녀의 일상     blog.naver.com/limhyunae  20260410
# 17                           30's Mood      blog.naver.com/reebbang  20260213
# 18                             밀크티 책세상       blog.naver.com/sandhya  20260306
# 19                           국가과학기술연구회  blog.naver.com/nststory2014  20260414
